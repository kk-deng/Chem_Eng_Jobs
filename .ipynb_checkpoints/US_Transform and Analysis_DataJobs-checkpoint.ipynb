# %% [markdown]
# # Data Tranformation

# %%
# Dependencies
import pandas as pd 
import numpy as np

# %%
filepath = f"CA_Data_jobs.csv"
df = pd.read_csv(filepath, index_col=0)
df
# Out:
#       Job Title Index               Job ID  \
# 0                   1   p_3ba18b41a5cb804f
# 1                   1   p_614e0392febe0ede
# 2                   1   p_a287b59453451899
# 3                   1  pj_16275b5a09d41ad4
# 4                   1   p_6d3b8c73d17db34b
# ...               ...                  ...
# 1296                7   p_b6e746a5587759a6
# 1297                7   p_ad53b9817257bfe6
# 1298                7   p_1046d7f83c7db93c
# 1299                7   p_ce1f1dba4c19b508
# 1300                7   p_01dd745b044c31c5
#
#                                               Job Title  \
# 0                                   Data Design Analyst
# 1                          Temporary - Research Analyst
# 2                                        Senior Analyst
# 3                            Analyst, HR and Technology
# 4                   Posting No. E2020-18 – Data Analyst
# ...                                                 ...
# 1296                          Senior Software Developer
# 1297  AWS Professional Services Associate Cloud Deve...
# 1298                        Embedded Software Developer
# 1299  Graphic Designer and Digital Marketing Specialist
# 1300                Principal Product Manager Technical
#
#                         Company Name Company Location  \
# 0                           Manulife      Toronto, ON
# 1                University Hospital       London, ON
# 2            Alberta Health Services      Calgary, AB
# 3                           UAP Inc.     Montréal, QC
# 4                      Maltby Centre           Canada
# ...                              ...              ...
# 1296              Koïos Intelligence     Montréal, QC
# 1297  Amazon Web Services Canada, In       Ottawa, ON
# 1298              Koïos Intelligence     Montréal, QC
# 1299              Koïos Intelligence     Montréal, QC
# 1300  AMZN CAN Fulfillment Svcs, ULC      Toronto, ON
#
#                                                    Link
# 0     https://ca.indeed.com/rc/clk?jk=3ba18b41a5cb80...
# 1     https://ca.indeed.com/rc/clk?jk=614e0392febe0e...
# 2     https://ca.indeed.com/rc/clk?jk=a287b594534518...
# 3     https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 4     https://ca.indeed.com/rc/clk?jk=6d3b8c73d17db3...
# ...                                                 ...
# 1296  https://ca.indeed.com/rc/clk?jk=b6e746a5587759...
# 1297  https://ca.indeed.com/rc/clk?jk=ad53b9817257bf...
# 1298  https://ca.indeed.com/rc/clk?jk=1046d7f83c7db9...
# 1299  https://ca.indeed.com/rc/clk?jk=ce1f1dba4c19b5...
# 1300  https://ca.indeed.com/rc/clk?jk=01dd745b044c31...
#
# [1301 rows x 6 columns]

# %%
# Drop duplicates and reset index

df.drop_duplicates(subset=['Job ID'],keep='first', inplace=True, ignore_index=True)
df.reset_index()
df
# Out:
#      Job Title Index               Job ID  \
# 0                  1   p_3ba18b41a5cb804f
# 1                  1   p_614e0392febe0ede
# 2                  1   p_a287b59453451899
# 3                  1  pj_16275b5a09d41ad4
# 4                  1   p_6d3b8c73d17db34b
# ..               ...                  ...
# 955                7  pj_ed60054d6b28bf07
# 956                7  pj_1f4bec165b1e2df6
# 957                7  pj_cf362ac3d80178f5
# 958                7   p_4712cefe2edd6f63
# 959                7  pj_860703c07b377fa6
#
#                                              Job Title  \
# 0                                  Data Design Analyst
# 1                         Temporary - Research Analyst
# 2                                       Senior Analyst
# 3                           Analyst, HR and Technology
# 4                  Posting No. E2020-18 – Data Analyst
# ..                                                 ...
# 955  Cloud Infrastructure Developer (Microsoft Azur...
# 956  Customer Support / Inside Sales Representative...
# 957  Inside Sales Representative (Bilingual French ...
# 958                       Software Development Manager
# 959                       Senior Application Developer
#
#                        Company Name Company Location  \
# 0                          Manulife      Toronto, ON
# 1               University Hospital       London, ON
# 2           Alberta Health Services      Calgary, AB
# 3                          UAP Inc.     Montréal, QC
# 4                     Maltby Centre           Canada
# ..                              ...              ...
# 955                          Procom    Vancouver, BC
# 956                 Just Sales Jobs  Mississauga, ON
# 957                 Just Sales Jobs     Brampton, ON
# 958  Amazon Web Services Canada, In    Vancouver, BC
# 959      Johnson Service Group Inc.      Calgary, AB
#
#                                                   Link
# 0    https://ca.indeed.com/rc/clk?jk=3ba18b41a5cb80...
# 1    https://ca.indeed.com/rc/clk?jk=614e0392febe0e...
# 2    https://ca.indeed.com/rc/clk?jk=a287b594534518...
# 3    https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 4    https://ca.indeed.com/rc/clk?jk=6d3b8c73d17db3...
# ..                                                 ...
# 955  https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 956  https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 957  https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
# 958  https://ca.indeed.com/rc/clk?jk=4712cefe2edd6f...
# 959  https://ca.indeed.com/pagead/clk?mo=r&ad=-6NYl...
#
# [960 rows x 6 columns]

# %%
# Remove the Link column
df = df[["Job Title Index", "Job ID", "Job Title", "Company Name", "Company Location"]]

df.head()
# Out:
#    Job Title Index               Job ID                            Job Title  \
# 0                1   p_3ba18b41a5cb804f                  Data Design Analyst
# 1                1   p_614e0392febe0ede         Temporary - Research Analyst
# 2                1   p_a287b59453451899                       Senior Analyst
# 3                1  pj_16275b5a09d41ad4           Analyst, HR and Technology
# 4                1   p_6d3b8c73d17db34b  Posting No. E2020-18 – Data Analyst
#
#               Company Name Company Location
# 0                 Manulife      Toronto, ON
# 1      University Hospital       London, ON
# 2  Alberta Health Services      Calgary, AB
# 3                 UAP Inc.     Montréal, QC
# 4            Maltby Centre           Canada

# %%
# Check if there is any is null in the dataframe
df.isnull().sum()
# Out:
# Job Title Index     0
# Job ID              0
# Job Title           0
# Company Name        0
# Company Location    0
# dtype: int64

# %%
# Find unique job titles and count
df["Job Title"].value_counts()
# Out:
# Business Analyst                                  41
# Data Scientist                                    21
# Data Engineer                                     20
# Senior Business Analyst                           16
# Data Analyst                                      14
#                                                   ..
# Agile Tools Analyst - 300273                       1
# Software Developer - Advanced Technology Group     1
# Business Analyst, Finance                          1
# Staff Backend Developer                            1
# Business (Sales) Analyst                           1
# Name: Job Title, Length: 780, dtype: int64

# %%
# Group by location and count
df_location = df.groupby(["Company Location"]).count()
df_location = df_location[["Job ID"]].sort_values(["Job ID"], ascending=False)
df_location.head(50)
# Out:
#                                        Job ID
# Company Location
# Toronto, ON                               268
# Montréal, QC                              146
# Vancouver, BC                             113
# Ottawa, ON                                 40
# Calgary, AB                                34
# Canada                                     33
# Edmonton, AB                               29
# Mississauga, ON                            25
# Winnipeg, MB                               14
# Remote                                     14
# Halifax, NS                                11
# Waterloo, ON                               10
# Quebec City, QC                            10
# Ontario                                     9
# Oakville, ON                                9
# North York, ON                              8
# Brampton, ON                                8
# Surrey, BC                                  8
# Kitchener, ON                               8
# Regina, SK                                  8
# Markham, ON                                 8
# Burnaby, BC                                 8
# London, ON                                  7
# Victoria, BC                                7
# Thornhill, ON                               6
# Alberta                                     5
# Saskatoon, SK                               4
# Cambridge, ON                               4
# British Columbia                            4
# St. John's, NL                              4
# Richmond Hill, ON                           4
# North Vancouver, BC                         3
# Saint-Césaire, QC                           3
# Saskatchewan                                3
# Hamilton, ON                                3
# Guelph, ON                                  3
# Greater Toronto Area, ON                    3
# Windsor, ON                                 3
# Dartmouth, NS                               3
# Welwyn, SK                                  2
# Aurora, ON                                  2
# Richmond, BC                                2
# Bolton, ON                                  2
# Metro Vancouver Regional District, BC       2
# Saint-Laurent, QC                           2
# Dorval, QC                                  2
# Etobicoke, ON                               2
# Saskatchewan, MB                            1
# Shawinigan, QC                              1
# 100 Mile House, BC                          1

# %%
# Filter job titles that has string "Remote" 

df_remote = df[df['Job Title'].str.contains('Remote', na=False, regex=False)]
df_remote
# Out:
#      Job Title Index               Job ID  \
# 41                 1   p_e38bd07bb051a594
# 232                3   p_fd8601f917b1363d
# 296                6   p_199485869e03c217
# 332                6   p_b7a25ed55ea0da2d
# 401                6  pj_a1425d215c110885
# 560                7   p_152e2a2114baf8bc
# 672                7   p_089813c0e82fb675
#
#                                              Job Title      Company Name  \
# 41                        Senior Data Analyst - Remote            Tucows
# 232                      Senior Data Engineer (Remote)            SSENSE
# 296  Product Manager - Data Analytics & Platform (R...              Yelp
# 332         Product Manager - Experimentation (Remote)              Yelp
# 401                 Business Analyst (Remote Position)  thirdstream inc.
# 560  Regional Sales Manager, Public Sector - Toront...       CrowdStrike
# 672         Sr. Consultant, Incident Response (Remote)       CrowdStrike
#
#     Company Location
# 41       Toronto, ON
# 232     Montréal, QC
# 296      Toronto, ON
# 332      Toronto, ON
# 401      Halifax, NS
# 560          Ontario
# 672          Alberta

# %%
# Find unique job titles and count
df_remote["Job Title"].value_counts()
# Out:
# Sr. Consultant, Incident Response (Remote)                  1
# Business Analyst (Remote Position)                          1
# Product Manager - Data Analytics & Platform (Remote)        1
# Product Manager - Experimentation (Remote)                  1
# Senior Data Engineer (Remote)                               1
# Regional Sales Manager, Public Sector - Toronto (Remote)    1
# Senior Data Analyst - Remote                                1
# Name: Job Title, dtype: int64

# %%
# Filter job titles that has string "Junior" 

df_junior = df[df['Job Title'].str.contains('Junior', na=False, regex=False)]
df_junior
# Out:
#      Job Title Index               Job ID  \
# 121                2   p_b00e7e0d2aa26efe
# 143                2   p_3502404efda09422
# 186                3  pj_be9fa0e1cebd79c9
# 272                6   p_0fbfb36690909dd0
# 403                6   p_4ed2585a82a91678
# 409                6   p_d8997e0e3da23e22
# 498                6  pj_d72f0bcc1c0715cd
# 499                6  pj_d32d18c75dad175a
# 656                7   p_e33926d13c8bc036
# 798                7   p_66fb9eb63f8e0d93
#
#                                              Job Title  \
# 121                              Junior Data Scientist
# 143                              Junior Data Scientist
# 186  Junior Java/ Big Data (Hadoop Ecosystem) Devel...
# 272                            Junior Business Analyst
# 403                            Junior Business Analyst
# 409                            Junior Business Analyst
# 498                            Junior Business Analyst
# 499                   Junior Business Analyst - 300186
# 656                Chef de projets techniques - Junior
# 798                 Junior Cloud .Net Developer - 2021
#
#                                  Company Name          Company Location
# 121  Global Spatial Technology Solutions Inc.             Dartmouth, NS
# 143                               Indigo Park               Toronto, ON
# 186                                    Procom               Toronto, ON
# 272                   Modern Cleaning Concept               Lasalle, QC
# 403                                       DXC              Saskatchewan
# 409                                      PHSA             Vancouver, BC
# 498                   York Group of Companies               Concord, ON
# 499                                    Procom               Toronto, ON
# 656                      InMédia Technologies              Montréal, QC
# 798                                       BDO  Greater Toronto Area, ON

# %%
# Find unique job titles and count
df_junior["Job Title"].value_counts()
# Out:
# Junior Business Analyst                                        4
# Junior Data Scientist                                          2
# Junior Java/ Big Data (Hadoop Ecosystem) Developer - 300484    1
# Junior Business Analyst - 300186                               1
# Chef de projets techniques - Junior                            1
# Junior Cloud .Net Developer - 2021                             1
# Name: Job Title, dtype: int64

# %%
# Group by location and count
df_junior_location = df_junior.groupby(["Company Location"]).count()
df_junior_location = df_junior_location[["Job ID"]].sort_values(["Job ID"], ascending=False)
df_junior_location.head(50)
# Out:
#                           Job ID
# Company Location
# Toronto, ON                    3
# Concord, ON                    1
# Dartmouth, NS                  1
# Greater Toronto Area, ON       1
# Lasalle, QC                    1
# Montréal, QC                   1
# Saskatchewan                   1
# Vancouver, BC                  1

# %%
# Filter job titles that has string "Jr" 

df_jr = df[df['Job Title'].str.contains('Jr', na=False, regex=False)]
df_jr
# Out:
#      Job Title Index               Job ID  \
# 493                6  pj_98115709f59dac4b
# 533                7   p_7334d2193fcab816
#
#                                 Job Title   Company Name Company Location
# 493  Business Analyst/Jr. Project Manager        Aerotek      Toronto, ON
# 533                Jr. Software Developer  STEP Software       London, ON

# %%
# Find unique job titles and count
df_jr["Job Title"].value_counts()
# Out:
# Business Analyst/Jr. Project Manager    1
# Jr. Software Developer                  1
# Name: Job Title, dtype: int64

# %%
# Group by location and count
df_jr_location = df_jr.groupby(["Company Location"]).count()
df_jr_location = df_jr_location[["Job ID"]].sort_values(["Job ID"], ascending=False)
df_jr_location.head(50)
# Out:
#                   Job ID
# Company Location
# London, ON             1
# Toronto, ON            1

# %%
# Filter job titles that has string "Entry" 

df_Entry = df[df['Job Title'].str.contains('Entry', na=False, regex=False)]
df_Entry
# Out:
#      Job Title Index              Job ID  \
# 454                6  p_7f1fca388d54fb3b
#
#                                              Job Title  \
# 454  Entry Level Functional Consultant, Dynamics 36...
#
#                   Company Name Company Location
# 454  Encore Business Solutions     Winnipeg, MB

# %%
# Find unique job titles and count
df_Entry["Job Title"].value_counts()
# Out:
# Entry Level Functional Consultant, Dynamics 365 Business Cen...    1
# Name: Job Title, dtype: int64

# %%
# Group by location and count
df_Entry_location = df_Entry.groupby(["Company Location"]).count()
df_Entry_location = df_Entry_location[["Job ID"]].sort_values(["Job ID"], ascending=False)
df_Entry_location.head(50)
# Out:
#                   Job ID
# Company Location
# Winnipeg, MB           1
